# %% [markdown]
# <span style="font-size:100%">
#
# 수업은 모두 열심히 들으셨나요?
#
# 간혹 강의에서 언급되지 않은 내용이 문제로 나올 수 있습니다.<br>
# 그럴땐 강의 내용 외 문제는 구글링을 통해 해결해주세요<br></span>
# <span style="font-size:80%">
# (구글링 또한 개발자가 갖쳐야할 역량 중에 하나랍니다 😊)
# </span>
#
# ---

# %% [markdown]
# <span style="font-size:80%">[문제1]<br><br></span>
# 세트 money의 결과로 올바른 것을 골라주세요
#
# money = { '만원', '만원', '오만원', '백원', '오만원', '십원' }
#
# 1. { '백원', '십원' }
# 2. {'만원', '백원', '십원', '오만원'}
# 3. {'만원', '백원', '십원'}
# 4. {'만원',  '오만원'}

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 2. {'만원', '백원', '십원', '오만원'}
# set은 순서가 없어서 출력하면 요소가 다르게 나오며 중복 또한 없앤다

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제2]<br><br></span>
# 세트 x = {3, 6, 9} 그리고 y = {1, 2, 3}가 있을 때, 집합 연산의 결과로 잘못된 것을 모두 고르세요
#
# 1. set.union(x, y)는 {1, 2, 3, 6, 9}
# 2. x ^ y는 {1, 3, 6}
# 3. x - y는 {6, 9}
# 4. x & y는 { 3 }
# 5. set.difference(y, x)는 { 2 }

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 2, 5
#
# 2 : '^' 이 연산자는 대칭 차집합으로 각 세트에만 포함된 요소를 반환하므로 1,2,6,9 이다.
#
# 5 : y에서 x의 요소를 제거한 차집합이므로 1,2이다.

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제3]<br><br></span>
# 과일 바구니 안에 두리안이 있는지 확인하기 위한 코드를 작성해 주세요
#
# 과일_바구니 = {'사과', '포도', '샤인머스켓', '두리안'}

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# '두리안' in 과일_바구니

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제4]<br><br></span>
# 메서드와 연산자의 기능이 잘못 짝지어진 것을 골라주세요
#
# 1. set.intersection은 &와 같다.
# 2. set.update는 |=와 같다.
# 3. symmetric_difference_update는 -=와 같다.
# 4. issuperset은 >와 같다.
# 5. set.union은 |와 같다.

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 3. symmetric_difference_update는 -=와 같다.
# :symmetric_difference_update는  두 집합의 대칭 차집합을 구한 후, 이를 현재 집합에 덮어쓰는 메서드로 '^=' 연산자와 같다

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제5]<br><br></span>
# 세트를 만드는 방법으로 올바르지 않은 것을 골라주세요
#
# 1. x = {1, 2, 3, 4, 5}
# 2. x = { }
# 3. x = set('hello')
# 4. x  = set(range(10))
# 5. x = set()

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 2. x={}
#
#  {}는 빈 딕셔너리 생성이다.
